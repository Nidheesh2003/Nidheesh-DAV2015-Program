# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidheesh2003/Nidheesh-DAV2015-Program/blob/main/20211CCS0172_Pandas_D_F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To create a Dataframe

# %%
import pandas as pd

data={
    "calories":[420,380,390],
    "duration":[50,40,45]

}

#load data into a dataframe object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# To locate the rows in Dataframe

# %%
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# To name the index

# %%
data={
    "calories":[420,380,390],
    "duration":[50,40,45]
}

df=pd.DataFrame(data, index=["day1","day2","day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# To locate Named index

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Nyc weather csv

# %%
df = pd.read_csv("nyc_weather.csv")
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %% [markdown]
# # New Section

# %%
df.shape
# Out:
# (31, 11)

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df.count()
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
df.isnull()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   False        False     False     False                 False
# 1   False        False     False     False                 False
# 2   False        False     False     False                 False
# 3   False        False     False     False                 False
# 4   False        False     False     False                 False
# 5   False        False     False     False                 False
# 6   False        False     False     False                 False
# 7   False        False     False     False                 False
# 8   False        False     False     False                 False
# 9   False        False     False     False                 False
# 10  False        False     False     False                 False
# 11  False        False     False     False                 False
# 12  False        False     False     False                 False
# ...

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.fillna(value=1234, inplace=True)

# %%
df.isnull()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   False        False     False     False                 False
# 1   False        False     False     False                 False
# 2   False        False     False     False                 False
# 3   False        False     False     False                 False
# 4   False        False     False     False                 False
# 5   False        False     False     False                 False
# 6   False        False     False     False                 False
# 7   False        False     False     False                 False
# 8   False        False     False     False                 False
# 9   False        False     False     False                 False
# 10  False        False     False     False                 False
# 11  False        False     False     False                 False
# 12  False        False     False     False                 False
# ...
